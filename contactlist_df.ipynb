# %%
import pandas as pd
contacts_df = pd.read_csv('contacts.csv')
contacts_df.head(1)
# Out:
#                 Name                            Number  Gender  Met  Network
# 0               Abel                      054 539 0365    male  yes      mtn
# 1         Abigail_IT                      054 156 6885  female  yes      mtn
# 2      Abraham's_dad                      024 238 4751    male  yes      mtn
# 3         AdawuduSey                      020 195 6052    male  yes  telecel
# 4               Addy                      024 523 5075    male  yes      mtn
# ..               ...                               ...     ...  ...      ...
# 366          Xorlali                      024 634 1049  female  yes      mtn
# 367  Xstar Lil Whyte                      054 553 3891  female  yes      mtn
# 368         Yohannes                      054 528 5023    male  yes      mtn
# 369      Yvonne_uenr                      054 395 3862  female  yes      mtn
# 370             Zita  055 336 6809 ::: +44 7551 622997  female  yes    other
#
# [371 rows x 5 columns]

# %%
contacts_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 371 entries, 0 to 370
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Name     371 non-null    object
#  1   Number   371 non-null    object
#  2   Gender   371 non-null    object
#  3   Met      371 non-null    object
#  4   Network  371 non-null    object
# dtypes: object(5)
# memory usage: 14.6+ KB

# %%
contacts_df.duplicated().value_counts()
# Out:
# False    371
# Name: count, dtype: int64

# %%
contacts_df.isnull().value_counts()
# Out:
# Name   Number  Gender  Met    Network
# False  False   False   False  False      371
# Name: count, dtype: int64

# %%
contacts_df.columns
# Out:
# Index(['Name', 'Number', 'Gender', 'Met', 'Network'], dtype='object')

# %%
contacts_df.Gender.unique()
# Out:
# array(['male', 'female'], dtype=object)

# %%
contacts_df.Met.unique()
# Out:
# array(['yes', 'no'], dtype=object)

# %%
contacts_df.Network.unique()
# Out:
# array(['mtn', 'telecel', 'at', 'other'], dtype=object)

# %%
#total number of males and females on my contact list
contacts_df.Gender.value_counts()
# Out:
# Gender
# male      240
# female    131
# Name: count, dtype: int64

# %%
#persons met
contacts_df.Met.value_counts()
# Out:
# Met
# yes    346
# no      25
# Name: count, dtype: int64

# %%
#persons met by gender
contacts_df[['Gender', 'Met']].value_counts().sort_index(ascending=False)
# Out:
# Gender  Met
# male    yes    230
#         no      10
# female  yes    116
#         no      15
# Name: count, dtype: int64

# %%
#the top network used
contacts_df.Network.value_counts().sort_values(ascending=True)
# Out:
# Network
# other       10
# at          36
# telecel     70
# mtn        255
# Name: count, dtype: int64

# %%
#number of males and females using the various networks
contacts_df[['Network', 'Gender']].value_counts().sort_index()
# Out:
# Network  Gender
# at       female     11
#          male       25
# mtn      female     94
#          male      161
# other    female      4
#          male        6
# telecel  female     22
#          male       48
# Name: count, dtype: int64

# %% [markdown]
# VISUALIZATION

# %%
#total number of males and females on the contact list
import matplotlib.pyplot as plt
import seaborn as sbn

sbn.set_style('darkgrid')
contacts_df.Gender.value_counts().plot(kind='bar')
plt.title('Gender Distribution of Contact List')
plt.ylabel('Frequency')
plt.xticks(rotation=75)
# Out:
# (array([0, 1]), [Text(0, 0, 'male'), Text(1, 0, 'female')])

# %%
#persons met
import matplotlib.pyplot as plt
import seaborn as sbn

sbn.set_style('white')
plt.figure(figsize=(5,5))
#contacts_df.Met.value_counts().plot(kind='bar', color = ['g', 'r'])
contacts_df.Met.value_counts().plot(kind='pie')
plt.legend()
plt.xticks(rotation=70)
plt.xlabel('Persons Met')
plt.title('Persons Met Distribution')
# Out:
# Text(0.5, 1.0, 'Persons Met Distribution')

# %%
#persons met by gender
import matplotlib.pyplot as plt
import seaborn as sbn

sbn.set_style('darkgrid')
plt.figure(figsize=(5,4))
#contacts_df[['Gender', 'Met']].value_counts().sort_index(ascending=True).plot(kind='barh', color=['r','g'])
contacts_df[['Gender', 'Met']].value_counts().sort_index(ascending=False).plot(kind='bar', color=['g','r'])
plt.xticks(rotation=70)
plt.title('Persons Met by Gender')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
#the top network used
import matplotlib.pyplot as plt
import seaborn as sbn


sbn.set_style('darkgrid')
#plt.figure(figsize=(6,4))
#plt.plot(contacts_df.Network.value_counts(), marker='*', color='r')
contacts_df.Network.value_counts().sort_values(ascending=True).plot(kind='barh', color=(['g','b','r','y']))
#plt.xticks(rotation=75)
#plt.yticks(rotation=70)
plt.xlabel('Frequency')
plt.ylabel('Network')
plt.title('Network Distribuution of Contacts')
# Out:
# Text(0.5, 1.0, 'Network Distribuution of Contacts')

# %%
import matplotlib.pyplot as plt
import seaborn as sbn

sbn.set_style('dark')
contacts_df.Met.value_counts().plot(kind='pie')
plt.legend()
plt.title('Persons Met Distribution')
# Out:
# Text(0.5, 1.0, 'Persons Met Distribution')

# %%
import matplotlib.pyplot as plt
import seaborn as sbn

sbn.set_style('darkgrid')
#plt.bar(contacts_df[['Network', 'Gender']].value_counts().sort_index())
#contacts_df[['Network', 'Gender']].value_counts().sort_index().plot(kind='bar')
contacts_df[['Network', 'Gender']].value_counts().sort_index().plot(kind='bar', color=['b','b','y','y','g','g','r','r'])

plt.xticks(rotation=80)
plt.ylabel('Frequency')
plt.title('Network Distribution by Gender')
#plt.bar_label(label_type=Literal['center'])
# Out:
# Text(0.5, 1.0, 'Network Distribution by Gender')
